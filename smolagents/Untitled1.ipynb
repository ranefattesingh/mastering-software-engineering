# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from smolagents import CodeAgent, WebSearchTool, InferenceClientModel

agent = CodeAgent(tools=[WebSearchTool()], model=InferenceClientModel())

agent.run("Search for the best music recommendations for a party at the Wayne's mansion.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for the best music recommendations for a party at the Wayne's mansion.                                   │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="best music for party at Wayne's mansion")
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'search_results = web_search(query="best music for party at Wayne's mansion")' due
# to: Exception: No results found! Try a less restrictive/shorter query.
# [Step 1: Duration 7.61 seconds| Input tokens: 2,093 | Output tokens: 1,384]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="best music for upscale mansion party")
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'search_results = web_search(query="best music for upscale mansion party")' due to:
# Exception: No results found! Try a less restrictive/shorter query.
# [Step 2: Duration 4.08 seconds| Input tokens: 4,425 | Output tokens: 1,893]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="luxury party music")
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'search_results = web_search(query="luxury party music")' due to: Exception: No
# results found! Try a less restrictive/shorter query.
# [Step 3: Duration 8.56 seconds| Input tokens: 6,960 | Output tokens: 3,367]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="best music for party")
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'search_results = web_search(query="best music for party")' due to: Exception: No
# results found! Try a less restrictive/shorter query.
# [Step 4: Duration 3.21 seconds| Input tokens: 9,693 | Output tokens: 3,789]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("Jazz, classical, and sophisticated pop music like Frank Sinatra, Ella Fitzgerald, and modern hits
#   such as 'Uptown Funk' or 'Blinding Lights' are perfect for a Wayne's mansion party.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Jazz, classical, and sophisticated pop music like Frank Sinatra, Ella Fitzgerald, and modern hits
# such as 'Uptown Funk' or 'Blinding Lights' are perfect for a Wayne's mansion party.
# [Step 5: Duration 14.92 seconds| Input tokens: 12,623 | Output tokens: 6,552]
# "Jazz, classical, and sophisticated pop music like Frank Sinatra, Ella Fitzgerald, and modern hits such as 'Uptown Funk' or 'Blinding Lights' are perfect for a Wayne's mansion party."

# %%
from smolagents import CodeAgent, tool

@tool
def suggest_menu(occasion: str) -> str:
    """
    Suggests a menu based on the occasion.
    Args:
        occasion (str): The type of occasion for the party. Allowed values are:
                        - "casual": Menu for casual party.
                        - "formal": Menu for formal party.
                        - "superhero": Menu for superhero party.
                        - "custom": Custom menu.
    """
    if occasion == "casual":
        return "Pizza, snacks, and drinks."
    elif occasion == "formal":
        return "3-course dinner with wine and dessert."
    elif occasion == "superhero":
        return "Buffet with high-energy and healthy food."
    else:
        return "Custom menu for the butler."

agent = CodeAgent(tools=[suggest_menu], model=InferenceClientModel())

agent.run("Prepare a formal menu for the party.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Prepare a formal menu for the party.                                                                            │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   menu = suggest_menu(occasion="formal")
#   final_answer(menu)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 3-course dinner with wine and dessert.
# [Step 1: Duration 3.21 seconds| Input tokens: 2,112 | Output tokens: 398]
# '3-course dinner with wine and dessert.'

# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 22.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: numpy
# Successfully installed numpy-2.4.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from smolagents import CodeAgent, InferenceClientModel
import numpy as np
import time
import datetime

agent = CodeAgent(tools=[], model=InferenceClientModel(), additional_authorized_imports=['datetime'])

agent.run(
    """
    Alfred needs to prepare for the party. Here are the tasks:
    1. Prepare the drinks - 30 minutes
    2. Decorate the mansion - 60 minutes
    3. Set up the menu - 45 minutes
    3. Prepare the music and playlist - 45 minutes

    If we start right now, at what time will the party be ready?
    """
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Alfred needs to prepare for the party. Here are the tasks:                                                      │
# │     1. Prepare the drinks - 30 minutes                                                                          │
# │     2. Decorate the mansion - 60 minutes                                                                        │
# │     3. Set up the menu - 45 minutes                                                                             │
# │     3. Prepare the music and playlist - 45 minutes                                                              │
# │                                                                                                                 │
# │     If we start right now, at what time will the party be ready?                                                │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   total_minutes = 30 + 60 + 45 + 45
#   hours = total_minutes // 60
#   final_answer(f"{hours} hours")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 3 hours
# [Step 1: Duration 14.30 seconds| Input tokens: 2,111 | Output tokens: 2,809]
# '3 hours'

# %%
pip install gradio_client
# Out:
# Collecting gradio_client
#   Downloading gradio_client-2.5.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: fsspec in ./.env/lib/python3.12/site-packages (from gradio_client) (2026.4.0)
# Requirement already satisfied: httpx>=0.24.1 in ./.env/lib/python3.12/site-packages (from gradio_client) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.19.3 in ./.env/lib/python3.12/site-packages (from gradio_client) (1.17.0)
# Requirement already satisfied: packaging in ./.env/lib/python3.12/site-packages (from gradio_client) (26.2)
# Requirement already satisfied: typing-extensions~=4.0 in ./.env/lib/python3.12/site-packages (from gradio_client) (4.15.0)
# Requirement already satisfied: anyio in ./.env/lib/python3.12/site-packages (from httpx>=0.24.1->gradio_client) (4.13.0)
# Requirement already satisfied: certifi in ./.env/lib/python3.12/site-packages (from httpx>=0.24.1->gradio_client) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in ./.env/lib/python3.12/site-packages (from httpx>=0.24.1->gradio_client) (1.0.9)
# Requirement already satisfied: idna in ./.env/lib/python3.12/site-packages (from httpx>=0.24.1->gradio_client) (3.17)
# Requirement already satisfied: h11>=0.16 in ./.env/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio_client) (0.16.0)
# Requirement already satisfied: click>=8.4.0 in ./.env/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.19.3->gradio_client) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in ./.env/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.19.3->gradio_client) (3.29.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in ./.env/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.19.3->gradio_client) (1.5.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.env/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.19.3->gradio_client) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in ./.env/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.19.3->gradio_client) (4.67.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in ./.env/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.19.3->gradio_client) (0.25.1)
# Requirement already satisfied: shellingham>=1.3.0 in ./.env/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.19.3->gradio_client) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in ./.env/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.19.3->gradio_client) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./.env/lib/python3.12/site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.19.3->gradio_client) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.env/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.19.3->gradio_client) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.env/lib/python3.12/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.19.3->gradio_client) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in ./.env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.19.3->gradio_client) (0.1.2)
# Downloading gradio_client-2.5.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: gradio_client
# Successfully installed gradio_client-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from smolagents import CodeAgent, InferenceClientModel, Tool

image_generation_tool = Tool.from_space(
    "black-forest-labs/FLUX.1-schnell",
    name="image_generator",
    description="Generate an image from a prompt"
)

model = InferenceClientModel("Qwen/Qwen2.5-Coder-32B-Instruct")

agent = CodeAgent(tools=[image_generation_tool], model=model)

agent.run(
    "Improve this prompt, then generate an image of it.",
    additional_args={'user_prompt': 'A grand superhero-themed party at Wayne Manor, with Alfred overseeing a luxurious gala'}
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 from smolagents import CodeAgent, InferenceClientModel, Tool
#       2
# ----> 3 image_generation_tool = Tool.from_space(
#       4     "black-forest-labs/FLUX.1-schnell",
#       5     name="image_generator",
#       6     description="Generate an image from a prompt"
#
# File ~/Workspace/mastering-software-engineering/smolagents/.env/lib/python3.12/site-packages/smolagents/tools.py:733, in Tool.from_space(space_id, name, description, api_name, token)
#     730             output = AgentAudio(output)
#     731         return output
# --> 733 return SpaceToolWrapper(
#     734     space_id=space_id,
#     735     name=name,
#     736     description=description,
#     737     api_name=api_name,
#     738     token=token,
#     739 )
#
# File ~/Workspace/mastering-software-engineering/smolagents/.env/lib/python3.12/site-packages/smolagents/tools.py:75, in validate_after_init.<locals>.new_init(self, *args, **kwargs)
#      73 @wraps(original_init)
#      74 def new_init(self, *args, **kwargs):
# ---> 75     original_init(self, *args, **kwargs)
#      76     self.validate_arguments()
#
# File ~/Workspace/mastering-software-engineering/smolagents/.env/lib/python3.12/site-packages/smolagents/tools.py:658, in Tool.from_space.<locals>.SpaceToolWrapper.__init__(self, space_id, name, description, api_name, token)
#     656 self.name = name
#     657 self.description = description
# --> 658 self.client = Client(space_id, hf_token=token)
#     659 space_api = self.client.view_api(return_format="dict", print_info=False)
#     660 assert isinstance(space_api, dict)
#
# TypeError: Client.__init__() got an unexpected keyword argument 'hf_token'

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel

# Initialize the search tool
search_tool = DuckDuckGoSearchTool()

# Initialize the model
model = InferenceClientModel()

agent = CodeAgent(
    model=model,
    tools=[search_tool],
)

# Example usage
response = agent.run(
    "Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering."
)
print(response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Workspace/mastering-software-engineering/smolagents/.env/lib/python3.12/site-packages/smolagents/default_tools.py:133, in DuckDuckGoSearchTool.__init__(self, max_results, rate_limit, **kwargs)
#     132 try:
# --> 133     from ddgs import DDGS
#     134 except ImportError as e:
#
# ModuleNotFoundError: No module named 'ddgs'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 4
#       1 from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel
#       2
#       3 # Initialize the search tool
# ----> 4 search_tool = DuckDuckGoSearchTool()
#       5
#       6 # Initialize the model
#       7 model = InferenceClientModel()
#
# File ~/Workspace/mastering-software-engineering/smolagents/.env/lib/python3.12/site-packages/smolagents/tools.py:75, in validate_after_init.<locals>.new_init(self, *args, **kwargs)
#      73 @wraps(original_init)
#      74 def new_init(self, *args, **kwargs):
# ---> 75     original_init(self, *args, **kwargs)
#      76     self.validate_arguments()
#
# File ~/Workspace/mastering-software-engineering/smolagents/.env/lib/python3.12/site-packages/smolagents/default_tools.py:135, in DuckDuckGoSearchTool.__init__(self, max_results, rate_limit, **kwargs)
#     133     from ddgs import DDGS
#     134 except ImportError as e:
# --> 135     raise ImportError(
#     136         "You must install package `ddgs` to run this tool: for instance run `pip install ddgs`."
#     137     ) from e
#     138 self.ddgs = DDGS(**kwargs)
#
# ImportError: You must install package `ddgs` to run this tool: for instance run `pip install ddgs`.
